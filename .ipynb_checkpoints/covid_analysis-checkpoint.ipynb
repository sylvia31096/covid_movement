# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cols_list=['baseline_name','baseline_type']
movement_df = pd.read_csv("data/movement_ken.csv")
movement_df.tail()
# Out:
#        Unnamed: 0          ds country polygon_source polygon_id  polygon_name  \
# 21660     2592445  2020-12-10     KEN           GADM  KEN.9.1_1  Isiolo North
# 21661     2592446  2020-12-11     KEN           GADM  KEN.9.1_1  Isiolo North
# 21662     2592447  2020-12-16     KEN           GADM  KEN.9.1_1  Isiolo North
# 21663     2592448  2020-12-18     KEN           GADM  KEN.9.1_1  Isiolo North
# 21664     2592449  2020-12-29     KEN           GADM  KEN.9.1_1  Isiolo North
#
#        all_day_bing_tiles_visited_relative_change  \
# 21660                                    -0.04408
# 21661                                     0.01453
# 21662                                     0.12100
# 21663                                     0.12762
# 21664                                     0.02708
#
#        all_day_ratio_single_tile_users  baseline_name baseline_type
# 21660                          0.15741  full_february   DAY_OF_WEEK
# 21661                          0.16013  full_february   DAY_OF_WEEK
# 21662                          0.11263  full_february   DAY_OF_WEEK
# 21663                          0.15152  full_february   DAY_OF_WEEK
# 21664                          0.15896  full_february   DAY_OF_WEEK

# %%
counties_df = pd.read_csv('data/other_subcounties_counties.csv')
counties_df.head()
# Out:
#    Unnamed: 0   county   constituencies
# 0           0  MOMBASA        CHANGAMWE
# 1           1  MOMBASA            JOMVU
# 2           2  MOMBASA          KISAUNI
# 3           3  MOMBASA           LIKONI
# 4           4  MOMBASA  MVITA (MOMBASA)

# %%
# merge counties
movement_df['polygon_name_upper'] = movement_df['polygon_name'].str.upper()
movement_merged_df = movement_df.merge(counties_df, how='left', left_on='polygon_name_upper', right_on='constituencies')
movement_merged_df.head()
# Out:
#    Unnamed: 0_x          ds country polygon_source  polygon_id  \
# 0       2570785  2020-03-01     KEN           GADM  KEN.10.1_1
# 1       2570786  2020-03-02     KEN           GADM  KEN.10.1_1
# 2       2570787  2020-03-03     KEN           GADM  KEN.10.1_1
# 3       2570788  2020-03-04     KEN           GADM  KEN.10.1_1
# 4       2570789  2020-03-05     KEN           GADM  KEN.10.1_1
#
#       polygon_name  all_day_bing_tiles_visited_relative_change  \
# 0  Kajiado Central                                    -0.14277
# 1  Kajiado Central                                    -0.18758
# 2  Kajiado Central                                    -0.07280
# 3  Kajiado Central                                    -0.02168
# 4  Kajiado Central                                    -0.01348
#
#    all_day_ratio_single_tile_users  baseline_name baseline_type  \
# 0                          0.16011  full_february   DAY_OF_WEEK
# 1                          0.09824  full_february   DAY_OF_WEEK
# 2                          0.12918  full_february   DAY_OF_WEEK
# 3                          0.10025  full_february   DAY_OF_WEEK
# 4                          0.11649  full_february   DAY_OF_WEEK
#
#   polygon_name_upper  Unnamed: 0_y   county   constituencies
# 0    KAJIADO CENTRAL           215  KAJIADO  KAJIADO CENTRAL
# 1    KAJIADO CENTRAL           215  KAJIADO  KAJIADO CENTRAL
# 2    KAJIADO CENTRAL           215  KAJIADO  KAJIADO CENTRAL
# 3    KAJIADO CENTRAL           215  KAJIADO  KAJIADO CENTRAL
# 4    KAJIADO CENTRAL           215  KAJIADO  KAJIADO CENTRAL

# %%
movement_merged_df.columns
# Out:
# Index(['Unnamed: 0_x', 'ds', 'country', 'polygon_source', 'polygon_id',
#        'polygon_name', 'all_day_bing_tiles_visited_relative_change',
#        'all_day_ratio_single_tile_users', 'baseline_name', 'baseline_type',
#        'polygon_name_upper', 'Unnamed: 0_y', 'county', 'constituencies'],
#       dtype='object')

# %%
movement_merged_df = movement_merged_df[['ds', 'polygon_name', 'all_day_bing_tiles_visited_relative_change',
       'all_day_ratio_single_tile_users', 'county']]
movement_merged_df.head()
# Out:
#            ds     polygon_name  all_day_bing_tiles_visited_relative_change  \
# 0  2020-03-01  Kajiado Central                                    -0.14277
# 1  2020-03-02  Kajiado Central                                    -0.18758
# 2  2020-03-03  Kajiado Central                                    -0.07280
# 3  2020-03-04  Kajiado Central                                    -0.02168
# 4  2020-03-05  Kajiado Central                                    -0.01348
#
#    all_day_ratio_single_tile_users   county
# 0                          0.16011  KAJIADO
# 1                          0.09824  KAJIADO
# 2                          0.12918  KAJIADO
# 3                          0.10025  KAJIADO
# 4                          0.11649  KAJIADO

# %%
movement_merged_df[movement_merged_df['county'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ds, polygon_name, all_day_bing_tiles_visited_relative_change, all_day_ratio_single_tile_users, county]
# Index: []

# %% [markdown]
# ## **Data distribution**

# %%
sns.displot(data=movement_merged_df, x='all_day_bing_tiles_visited_relative_change')

# %% [markdown]
# ## **Relationship Analysis**

# %%
g = sns.relplot(data=movement_merged_df,x='all_day_bing_tiles_visited_relative_change', y='all_day_ratio_single_tile_users')

# %%
sns.regplot(data=movement_merged_df, x='all_day_bing_tiles_visited_relative_change', y='all_day_ratio_single_tile_users')
# Out:
# <AxesSubplot:xlabel='all_day_bing_tiles_visited_relative_change', ylabel='all_day_ratio_single_tile_users'>

# %% [markdown]
# ### **Categorical**

# %%
plt.figure(figsize=(15,8))
sns.catplot(x="county", y="all_day_bing_tiles_visited_relative_change", jitter=False, data=movement_merged_df)

# %%
sns.pairplot(data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_63911/2096729710.py in <module>
# ----> 1 sns.pairplot(data=df)
#
# NameError: name 'df' is not defined

# %%
sns.barplot(data=df, y='all_day_ratio_single_tile_users', x='polygon_name')
# Out:
# <AxesSubplot:xlabel='polygon_name', ylabel='all_day_ratio_single_tile_users'>
